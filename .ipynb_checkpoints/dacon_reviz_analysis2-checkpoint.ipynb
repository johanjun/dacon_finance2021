# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='AppleGothic')
import seaborn as sns
import pickle
with open('df_corr_merge.pkl', 'rb') as f:
    df_corr_merge = pickle.load(f)

# %%
for c in df_corr_merge.columns:
    if ('서울' or 'x') in c:
        print(c)
# Out:
# 서울[호]_x
# 서울[2017.11=100]
# 종합-서울[2017.11=100]
# 아파트-서울[2017.11=100]
# 연립다세대-서울[2017.11=100]
# 단독주택-서울[2017.11=100]
# 서울[호]_y
# 아파트(서울)[2019.01=100]_x
# 총지수(서울)[2019.01=100]_x
# 아파트(서울)[2019.01=100]_y
# 총지수(서울)[2019.01=100]_y
# 서울[%]

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='date', y='아파트(서울)[2019.01=100]_x', data=df_corr_merge)
plt.show()

# %%
# df_corr_merge.to_csv('df_corr_merge.csv')

# %%
with open('li_pos.pkl', 'rb') as f:
    li_pos = pickle.load(f)
    
with open('li_neg.pkl', 'rb') as f:
    li_neg = pickle.load(f)

# %%
print(li_pos, '\n\n', li_neg)
# Out:
# ['선행종합지수(2015=100)' '아파트(서울)[2019.01=100]_x' '아파트[2019.01=100]_x'
#  '총지수[2019.01=100]_x' '광주[2017.11=100]' '연립주택[2019.01=100]_x'
#  '총지수(서울)[2019.01=100]_x' '지방광역시[2017.11=100]' '아파트[2019.01=100]_y'
#  '전국[2017.11=100]']
#
#  ['단독주택-5대광역시[2017.11=100]' '단독주택-울산[2017.11=100]' '단독주택-부산[2017.11=100]'
#  '단독주택-6대광역시[2017.11=100]' '연립다세대-세종[2017.11=100]' '연립다세대-충북[2017.11=100]'
#  '단독주택-지방[2017.11=100]' '연립다세대-충남[2017.11=100]' '아파트-경북[2017.11=100]'
#  '종합-경북[2017.11=100]']

# %%
df_line.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-02-01', '1970-03-01', '1970-04-01',
#                '1970-05-01', '1970-06-01', '1970-07-01', '1970-08-01',
#                '1970-09-01', '1970-10-01',
#                ...
#                '2020-06-01', '2020-07-01', '2020-08-01', '2020-09-01',
#                '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01',
#                '2021-02-01', '2021-03-01'],
#               dtype='datetime64[ns]', name='date', length=615, freq=None)

# %%
import datetime as dt

# %%
df_line = pd.DataFrame(df_corr_merge[df_corr_merge.index > dt.datetime(1989,12, 1)], columns=li_pos)

# %%
df_line.head()
# Out:
#             선행종합지수(2015=100)  아파트(서울)[2019.01=100]_x  아파트[2019.01=100]_x  \
# date
# 1990-01-01              27.8                  19.238              20.529
# 1990-02-01              28.0                  21.809              22.800
# 1990-03-01              28.1                  22.371              23.390
# 1990-04-01              28.3                  22.844              24.013
# 1990-05-01              28.4                  22.253              23.795
#
#             총지수[2019.01=100]_x  광주[2017.11=100]  연립주택[2019.01=100]_x  \
# date
# 1990-01-01              30.329              NaN               31.006
# 1990-02-01              33.942              NaN               35.354
# 1990-03-01              34.740              NaN               36.500
# 1990-04-01              35.538              NaN               37.742
# 1990-05-01              35.202              NaN               37.313
#
#             총지수(서울)[2019.01=100]_x  지방광역시[2017.11=100]  아파트[2019.01=100]_y  \
# date
# 1990-01-01                  28.600                 NaN              32.174
# 1990-02-01                  32.730                 NaN              33.758
# 1990-03-01                  33.470                 NaN              34.917
# 1990-04-01                  34.133                 NaN              36.577
# 1990-05-01                  33.198                 NaN              37.234
#
#             전국[2017.11=100]
# date
# 1990-01-01              NaN
# 1990-02-01              NaN
# 1990-03-01              NaN
# 1990-04-01              NaN
# 1990-05-01              NaN

# %%
df_line.shape
# Out:
# (375, 10)

# %%
# ?plt.legend

# %%
fig, axes = plt.subplots(3, 3, sharex=True, figsize=(18,9))
l = 1

for i in range(0, 3):
    for j in range(0, 3):
        fig.suptitle('Top 9 Positive to 선행종합지수', fontsize=30)
        sns.lineplot(x='date', y=li_pos[l], data=df_corr_merge, ax=axes[i, j])
        axes[i, j].set_title(li_pos[l])
        l += 1

plt.tight_layout()
plt.show()

# %%
li_pos
# Out:
# array(['선행종합지수(2015=100)', '아파트(서울)[2019.01=100]_x', '아파트[2019.01=100]_x',
#        '총지수[2019.01=100]_x', '광주[2017.11=100]', '연립주택[2019.01=100]_x',
#        '총지수(서울)[2019.01=100]_x', '지방광역시[2017.11=100]',
#        '아파트[2019.01=100]_y', '전국[2017.11=100]'], dtype=object)

# %%
fig, axes = plt.subplots(3, 3, sharex=True, figsize=(18,9))
l = 1

for i in range(0, 3):
    for j in range(0, 3):
        fig.suptitle('Top 9 Positive to 선행종합지수(diff)', fontsize=30)
        sns.lineplot(x='date', y=df_corr_merge[li_pos[l]].diff(periods=1).iloc[1:], data=df_corr_merge, ax=axes[i, j])
        axes[i, j].set_title(li_pos[l])
        l += 1

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
sns.set_style('whitegrid')
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='AppleGothic')
labels = df_line.columns
for i in df_line.columns[:6]:
    sns.lineplot(x='date', y=i, data=df_line)
plt.tight_layout()
plt.legend(labels=labels, loc='upper left')
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
sns.set_style('whitegrid')
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='AppleGothic')
labels = df_line.columns
for i in df_line.columns[:6]:
    sns.lineplot(x='date', y=df_line[i].diff(periods=1).iloc[1:], data=df_line)
plt.tight_layout()
plt.legend(labels=labels, loc='upper left')
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
sns.set_style('whitegrid')
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='AppleGothic')
labels = df_line.columns
for i in df_line.columns[:2]:
    sns.lineplot(x='date', y=df_line[i].diff(periods=1).iloc[1:], data=df_line)
plt.tight_layout()
plt.legend(labels=labels, loc='upper left')
plt.show()

# %%
df_line_diff = df_line.diff(periods=1)

# %%
df_line_diff.head()
# Out:
#             선행종합지수(2015=100)  아파트(서울)[2019.01=100]_x  아파트[2019.01=100]_x  \
# date
# 1990-01-01               NaN                     NaN                 NaN
# 1990-02-01               0.2                   2.571               2.271
# 1990-03-01               0.1                   0.562               0.590
# 1990-04-01               0.2                   0.473               0.623
# 1990-05-01               0.1                  -0.591              -0.218
#
#             총지수[2019.01=100]_x  광주[2017.11=100]  연립주택[2019.01=100]_x  \
# date
# 1990-01-01                 NaN              NaN                  NaN
# 1990-02-01               3.613              NaN                4.348
# 1990-03-01               0.798              NaN                1.146
# 1990-04-01               0.798              NaN                1.242
# 1990-05-01              -0.336              NaN               -0.429
#
#             총지수(서울)[2019.01=100]_x  지방광역시[2017.11=100]  아파트[2019.01=100]_y  \
# date
# 1990-01-01                     NaN                 NaN                 NaN
# 1990-02-01                   4.130                 NaN               1.584
# 1990-03-01                   0.740                 NaN               1.159
# 1990-04-01                   0.663                 NaN               1.660
# 1990-05-01                  -0.935                 NaN               0.657
#
#             전국[2017.11=100]
# date
# 1990-01-01              NaN
# 1990-02-01              NaN
# 1990-03-01              NaN
# 1990-04-01              NaN
# 1990-05-01              NaN

# %%
df_line_diff[df_line_diff['아파트(서울)[2019.01=100]_x'] < -1]
# Out:
#             선행종합지수(2015=100)  아파트(서울)[2019.01=100]_x  아파트[2019.01=100]_x  \
# date
# 1990-12-01               0.2                  -1.064              -0.716
# 1998-02-01              -0.6                  -1.182              -1.088
# 1998-03-01               0.3                  -2.275              -1.649
# 1998-04-01               0.6                  -2.926              -1.960
# 1998-05-01               0.3                  -1.684              -1.461
# 2002-11-01               0.1                  -1.389              -0.653
# 2008-12-01              -0.1                  -1.535              -0.841
#
#             총지수[2019.01=100]_x  광주[2017.11=100]  연립주택[2019.01=100]_x  \
# date
# 1990-12-01              -0.798              NaN               -0.477
# 1998-02-01              -1.093              NaN               -0.955
# 1998-03-01              -1.764              NaN               -2.150
# 1998-04-01              -2.310              NaN               -2.724
# 1998-05-01              -1.555              NaN               -1.576
# 2002-11-01              -0.588              NaN               -0.573
# 2008-12-01              -0.747             -0.9               -0.665
#
#             총지수(서울)[2019.01=100]_x  지방광역시[2017.11=100]  아파트[2019.01=100]_y  \
# date
# 1990-12-01                  -1.169                 NaN               0.270
# 1998-02-01                  -1.052                 NaN              -0.811
# 1998-03-01                  -2.455                 NaN              -1.159
# 1998-04-01                  -3.585                 NaN              -1.236
# 1998-05-01                  -1.558                 NaN              -1.159
# 2002-11-01                  -1.247                 NaN               0.000
# 2008-12-01                  -1.260                -0.7              -0.673
#
#             전국[2017.11=100]
# date
# 1990-12-01              NaN
# 1998-02-01              NaN
# 1998-03-01              NaN
# 1998-04-01              NaN
# 1998-05-01              NaN
# 2002-11-01              NaN
# 2008-12-01             -2.7

# %% [markdown]
# ### 1998년 4월

# %%
fig = plt.figure(figsize=(8,4))
sns.set_style('whitegrid')
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='AppleGothic')
labels = df_line.columns
y_ = df_line[(df_line.index > dt.datetime(1997, 1, 1)) & (df_line.index < dt.datetime(1998, 12, 1))].diff(periods=1)
for i in df_line.columns[:2]:
    sns.lineplot(x='date', y=y_[i], data=df_line)
plt.ylim([-3, 3])
plt.axvline(x=dt.datetime(1997, 10, 1), color='b', linewidth=2)
plt.axvline(x=dt.datetime(1998, 1, 1), color='r', linewidth=2)
plt.tight_layout()
plt.legend(labels=labels, loc='upper left')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
y_ = df_line[(df_line.index > dt.datetime(1997, 8, 1)) & (df_line.index < dt.datetime(1998, 7, 1))]
fig = plt.figure(figsize=(8,4))
sns.set_style('whitegrid')
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='AppleGothic')

sns.lineplot(x='date', y=y_['아파트(서울)[2019.01=100]_x'], data=df_line)
# Out:
# <AxesSubplot:xlabel='date', ylabel='아파트(서울)[2019.01=100]_x'>

# %%
y_ = df_line[(df_line.index > dt.datetime(1997, 8, 1)) & (df_line.index < dt.datetime(2001, 7, 1))]
fig = plt.figure(figsize=(8,4))
sns.set_style('whitegrid')
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='AppleGothic')

sns.lineplot(x='date', y=y_['아파트(서울)[2019.01=100]_x'], data=df_line)
# Out:
# <AxesSubplot:xlabel='date', ylabel='아파트(서울)[2019.01=100]_x'>

# %% [markdown]
# ### 2002년 11월

# %%
y_ = df_line[(df_line.index > dt.datetime(2002, 6, 1)) & (df_line.index < dt.datetime(2003, 7, 1))]
fig = plt.figure(figsize=(15,8))
sns.set_style('whitegrid')
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='AppleGothic')

sns.lineplot(x='date', y=y_['아파트(서울)[2019.01=100]_x'], data=df_line)
# Out:
# <AxesSubplot:xlabel='date', ylabel='아파트(서울)[2019.01=100]_x'>
